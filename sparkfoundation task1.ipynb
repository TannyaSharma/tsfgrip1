# %% [markdown]
# # THE SPARK FOUNDATION
# ## Data Science & Business Analyst Feb 21
# ### Author : TANNYA SHARMA
# ### Task 1 : Prediction using Supervised ML
# <b> QUERY: To predict the percentage of student who studied 9.25 hrs per day using given dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn import metrics

# %%
#to impory data from file
d=pd.read_csv("C:/Users/Lenovo/Documents/task1.csv")
print(d.head())
print(d.tail())
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
#     Hours  Scores
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
d.shape
# Out:
# (25, 2)

# %%
d.info
# Out:
# <bound method DataFrame.info of     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86>

# %%
print(d.isnull().sum())
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %% [markdown]
# <b>this shows that data does not have missing value

# %%
print(d.describe())
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %% [markdown]
# # 1. DATA VISUALIZATION

# %%
plt.scatter(d.Hours,d.Scores,color="blue",label="Score")
plt.xlabel("Number of Hours Studied")
plt.ylabel("Scores of Student(in %)")
plt.title("Study hours vs Percentage of student")
plt.legend()
plt.show()

# %% [markdown]
# <i>the above abtained graph shows that there is strong linear relationship between two variables thus making ideal condition to apply Linear Regression

# %% [markdown]
# # 2. Regression Model

# %%
sns.regplot(x=d['Hours'],y=d['Scores'],color='green')
plt.xlabel("Number of Hours Studied")
plt.ylabel("Scores of Student(in %)")
plt.title("Regression Plot",size=20)
plt.show()
print(d.corr())
# Out:
#            Hours    Scores
# Hours   1.000000  0.976191
# Scores  0.976191  1.000000

# %% [markdown]
# <b><i> this shows that data is positively correlated</i></b>

# %% [markdown]
# <i> now its time to split the dataset into train and test data

# %%
#defining x and y from dataset
X=d[['Hours']]
y=d['Scores']

#spliting of data
 
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.2, random_state=0)
X_train
# Out:
#     Hours
# 22    3.8
# 17    1.9
# 24    7.8
# 23    6.9
# 14    1.1
# 1     5.1
# 10    7.7
# 13    3.3
# 8     8.3
# 6     9.2
# 18    6.1
# 4     3.5
# 9     2.7
# 7     5.5
# 20    2.7
# 3     8.5
# 0     2.5
# 21    4.8
# 15    8.9
# 12    4.5

# %%
regression=LinearRegression()
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # 3.Predicting test data

# %%
y_pred=regression.predict(X_test)
prediction=pd.DataFrame({"hours":x_test,"percentage":y_pred})
prediction
# Out:
#     hours  percentage
# 15    8.9   16.884145
# 24    7.8   33.732261
# 14    1.1   75.357018
# 19    7.4   26.794801
# 13    3.3   60.491033

# %% [markdown]
# <b><i> now comparing the predicted percentage with real one

# %%
compare_score=pd.DataFrame({'Actual Marks':y_test,'Predicted Marks':y_pred})
compare_score
# Out:
#     Actual Marks  Predicted Marks
# 5             20        16.884145
# 2             27        33.732261
# 19            69        75.357018
# 16            30        26.794801
# 11            62        60.491033

# %% [markdown]
# # 4. Visualization of Predicted and Actual marks

# %%
plt.scatter(X_test,y_test,color="blue")
plt.plot(X_test,y_pred,color='red')
plt.xlabel("Number of Hours Studied")
plt.ylabel("Scores of Student(in %)")
plt.title("Study hours vs Percentage of student")
plt.show()

# %% [markdown]
# # 5. Accuracy of the Model and Prediction of Query

# %%
# accuracy of model
mean_abs_error=mean_absolute_error(y_test,y_pred)
print("mean_abs_error :",mean_abs_error)
print("R-2 Score:",metrics.r2_score(y_test,y_pred))
# Out:
# mean_abs_error : 4.183859899002975
# R-2 Score: 0.9454906892105356

# %%
# prection
Hours=[9.25]
answer=regression.predict([Hours])
print("Percentage of student who studied 9.25 hrs per day is:",format(round(answer[0],3)))
# Out:
# Percentage of student who studied 9.25 hrs per day is: 91.856

# %% [markdown]
# <b> Now from above score we can comment that our model is 94% accurate

# %% [markdown]
# <b><i> Hence, our task objective is reached .

# %% [markdown]
# ### THANK YOU
